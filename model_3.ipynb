# %%
import json
import torch
from torch.utils.data import Dataset, DataLoader
import torchtext.vocab as vocab
from torchtext.vocab import GloVe
import torch.nn as nn
from tqdm import tqdm
import numpy as np
import time
import torch.optim as optim
import matplotlib.pyplot as plt
from ordered_set import OrderedSet
import random
from transformers import BertModel
from transformers import BertTokenizer
# glove_dim=100
# glove = vocab.GloVe(name='6B', dim=glove_dim)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
special_tags=["<sos>","<eos>","<unk>","<pad>"]
symbols = ["(", ")", ",","|","const_"]
symbols.extend(range(10))
pos_special_tokens_prob=[0,0,0,0]
pos_special_tokens_sol=[0,0,0,0]
embed_dim=100
beam_size=10

# %%
def collate(batch):
    
    max_len_problem = max([len(sample[0]) for sample in batch])
    max_len_solution = max([len(sample[1]) for sample in batch])
    
    padded_prob = torch.empty((len(batch), max_len_problem), dtype=torch.long)
    padded_prob.fill_(0)
    padded_sol = torch.empty((len(batch), max_len_solution), dtype=torch.long)
    padded_sol.fill_(pos_special_tokens_sol[3])
    ans=torch.zeros(len(batch))
    prob_attn_mask = torch.zeros((len(batch), max_len_problem), dtype=torch.long)
    for idx in range(len(batch)):
        prob_len = len(batch[idx][0])
        ans[idx]=batch[idx][2]
        padded_prob[idx, :len(batch[idx][0])] = torch.LongTensor(batch[idx][0])
        padded_sol[idx, :len(batch[idx][1])] = torch.LongTensor(batch[idx][1])
        prob_attn_mask[idx, :prob_len] = torch.ones((1, prob_len), dtype=torch.long)
    return (padded_prob,padded_sol,prob_attn_mask,ans)

# %%
class load_data_train(Dataset):
    def __init__(self,json_path):
        self.path=json_path
        self.data=[]
        self.loaddata()
        self.problem_unique_words,self.sol_unique_words=self.gen_all_unique_words()
        self.problem_word2int = {word: i for i, word in enumerate(self.problem_unique_words)}
        self.problem_int2word = {i: word for word, i in self.problem_word2int.items()}
        self.sol_word2int = {word: i for i, word in enumerate(self.sol_unique_words)}
        self.sol_int2word = {i: word for word, i in self.sol_word2int.items()}
        self.max_problem_len=self.get_max_len()
        self.get_special_pos_prob()
        self.get_special_pos_sol()
        self.en_tokenizer =  BertTokenizer.from_pretrained("bert-base-cased")
    def get_special_pos_prob(self):
        for i,t in enumerate(special_tags):
            pos_special_tokens_prob[i]=self.problem_word2int[t]
            
    def get_special_pos_sol(self):
        for i,t in enumerate(special_tags):
            pos_special_tokens_sol[i]=self.sol_word2int[t]
            
    def gen_all_unique_words(self):
        u1=set(special_tags)
        u2=set(symbols+special_tags)
        for i,(prob,sol,a) in enumerate(self.data):
            for word in prob.split():
                u1.add(word)
            operations = sol.split("|")
            for operation in operations:
                if not operation:  
                    continue
                operation_name = operation.split("(")[0]
                u2.add(operation_name) 
                content = operation[operation.find("(")+1:operation.find(")")]
                tokens = content.split(",")
                u2.update(tokens)
        return u1,u2
    
    def tokanize_problem(self,i):
#         return self.data[i][0].split()
        return self.en_tokenizer.encode(self.data[i][0])
    
    def tokanize_sol(self,i):
        l=[]
        operations = self.data[i][1].split("|")
        for j,operation in enumerate(operations):
            if not operation:  
                continue
            operation_name = operation.split("(")[0]
            l.append(operation_name) 
            l.append("(")
            content = operation[operation.find("(")+1:operation.find(")")]
            tokens = content.split(",")
            new=[]
            for i, token in enumerate(tokens):
                new.append(token)
                if i < len(tokens) - 1:
                    new.append(",")
            l.extend(new)
            l.append(")")
            if j < len(operations) - 1:
                    l.append("|")
        return l
    
    def get_max_len(self):
        m=0
        for (p,s,a) in self.data:
            for p1 in p:
                m=max(m,len(p1.split()))
        return m

    def loaddata(self):
        with open(self.path, 'r') as f:
            data = json.load(f)
            for i in data:
                #list(i["Problem"].split())
#                 p=str(i["Problem"]).split()
                self.data.append((i["Problem"],i["linear_formula"],i["answer"]))
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, i):
        problem=self.tokanize_problem(i)
        sol=["<sos>"]+self.tokanize_sol(i)+["<eos>"]
#         problem = [self.problem_word2int[q] if q in self.problem_word2int else self.problem_word2int["<unk>"] for q in problem]
        sol = [self.sol_word2int[q] if q in self.sol_word2int else self.sol_word2int["<unk>"] for q in sol]
        return ((problem,sol,self.data[i][2]))

# %%
class load_data_test(Dataset):
    def __init__(self,json_path,train):
        self.path=json_path
        self.data=[]
        self.loaddata()
        self.problem_unique_words,self.sol_unique_words=train.problem_unique_words,train.sol_unique_words
        self.problem_word2int = train.problem_word2int
        self.problem_int2word = train.problem_int2word
        self.sol_word2int = train.sol_word2int
        self.sol_int2word =train.sol_int2word
        self.en_tokenizer =  BertTokenizer.from_pretrained("bert-base-cased")
    def tokanize_problem(self,i):
        return self.en_tokenizer.encode(self.data[i][0])
    
    def tokanize_sol(self,i):
        l=[]
        operations = self.data[i][1].split("|")
        for j,operation in enumerate(operations):
            if not operation:  
                continue
            operation_name = operation.split("(")[0]
            l.append(operation_name) 
            l.append("(")
            content = operation[operation.find("(")+1:operation.find(")")]
            tokens = content.split(",")
            new=[]
            for i, token in enumerate(tokens):
                new.append(token)
                if i < len(tokens) - 1:
                    new.append(",")
            l.extend(new)
            l.append(")")
            if j < len(operations) - 1:
                    l.append("|")
        return l

    def loaddata(self):
        with open(self.path, 'r') as f:
            data = json.load(f)
            for i in data:
                #list(i["Problem"].split())
#                 p=str(i["Problem"]).split()
                self.data.append((i["Problem"],i["linear_formula"],i["answer"]))
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, i):
        problem=self.tokanize_problem(i)
        sol=["<sos>"]+self.tokanize_sol(i)+["<eos>"]
#         problem = [self.problem_word2int[q] if q in self.problem_word2int else self.problem_word2int["<unk>"] for q in problem]
        sol = [self.sol_word2int[q] if q in self.sol_word2int else self.sol_word2int["<unk>"] for q in sol]
        return ((problem,sol,self.data[i][2]))

# %%
train_path="/kaggle/input/new-wp/data/train.json"
train_data=load_data_train(train_path)
train_loader = DataLoader(train_data, batch_size=64, shuffle=False, collate_fn=collate)

test_path="/kaggle/input/new-wp/data/test.json"
test_data=load_data_test(test_path,train_data)
test_loader = DataLoader(test_data, batch_size=1, shuffle=False, collate_fn=collate)



validation_path="/kaggle/input/new-wp/data/dev.json"
val_data=load_data_test(validation_path,train_data)
validation_loader = DataLoader(val_data, batch_size=64, shuffle=False, collate_fn=collate)
validation_loader1 = DataLoader(val_data, batch_size=1, shuffle=False, collate_fn=collate)
# Out:
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
class BERT_Encoder(nn.Module):
    def __init__(self):
        super(BERT_Encoder, self).__init__()
        self.bert = BertModel.from_pretrained('bert-base-cased')
        for param in self.bert.parameters():
            param.requires_grad = False

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        return outputs.last_hidden_state

# %%
class Attention(nn.Module):
    def __init__(self, enc_hid_dim=768, dec_hid_dim=128):
        super(Attention, self).__init__()
        self.attn = nn.Linear(enc_hid_dim + dec_hid_dim, dec_hid_dim)
        self.v = nn.Linear(dec_hid_dim, 1, bias=False)

    def forward(self, encoder_outputs, hidden):
        batch_size = encoder_outputs.shape[0]
        src_len = encoder_outputs.shape[1]
        hidden = hidden.unsqueeze(1).repeat(1, src_len, 1)  
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim=2))) 
        attention = self.v(energy).squeeze(2)
        return torch.softmax(attention, dim=1)

# %%
class LSTM_Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim=200, enc_hid_dim=768, dec_hid_dim=128, dropout=0.5):
        super(LSTM_Decoder, self).__init__()
        self.attention = Attention()
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.rnn = nn.LSTM(emb_dim + enc_hid_dim, dec_hid_dim, batch_first=True)
        self.fc_out = nn.Linear(enc_hid_dim + dec_hid_dim + emb_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden, cell, encoder_outputs):
        embedded = self.dropout(self.embedding(input.unsqueeze(1))) 
        attn_weighted = self.attention(encoder_outputs, hidden[0]) 
        attn_weighted = attn_weighted.unsqueeze(1) 
        weighted = torch.bmm(attn_weighted, encoder_outputs)  
        rnn_input = torch.cat((embedded, weighted), dim=2)  
        output, (hidden, cell) = self.rnn(rnn_input, (hidden, cell))
        prediction = self.fc_out(torch.cat((output, weighted, embedded), dim=2).squeeze(1))
        return prediction, hidden, cell

# %%
class Seq2Seq(nn.Module):
    def __init__(self,max_len_pred=None,device=device):
        super(Seq2Seq, self).__init__()
        self.encoder = BERT_Encoder()
        self.decoder = LSTM_Decoder(output_dim=max_len_pred)
        self.device = device

    def forward(self, src,trg, src_mask,  teacher_forcing_ratio=0.5):
        batch_size = src.shape[0]
        trg_len = trg.shape[1]
        trg_vocab_size = self.decoder.embedding.num_embeddings
        outputs = torch.zeros(batch_size, trg_len, trg_vocab_size).to(self.device)
        encoder_outputs = self.encoder(src, src_mask)
        hidden = torch.zeros(1, batch_size, self.decoder.rnn.hidden_size).to(self.device)
        cell = torch.zeros(1, batch_size, self.decoder.rnn.hidden_size).to(self.device)
        input = trg[:, 0]

        for t in range(1, trg_len):
            output, hidden, cell = self.decoder(input, hidden, cell, encoder_outputs)
            outputs[:, t, :] = output
            teacher_force = random.random() < teacher_forcing_ratio
            top1 = output.argmax(1)
            input = trg[:, t] if teacher_force else top1
        predicted_tokens = outputs.argmax(2) 
        return outputs,predicted_tokens

# %%
model=Seq2Seq(max_len_pred=len(train_data.sol_unique_words),device=device)
if torch.cuda.device_count() > 1:
    model = nn.DataParallel(model)
model=model.to(device)
def train(epochs):
    st=time.time()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    train_l=[]
    val_l=[]
    for epoch in range(epochs):
        print(f"=======================epoch {epoch}================================")
        model.train()
        l=[]
        for j,data1 in enumerate(train_loader):
            optimizer.zero_grad()
            x=data1[0].to(device)
            y=data1[1].to(device)
            att=data1[2].to(device)
            o,w=model(x,y,att,teacher_forcing_ratio=0.6)
            o = o.reshape(-1, o.shape[2]).to(device)
            y_orig = y.reshape(-1).to(device)
            loss = criterion(o, y_orig)
            loss.backward()
            optimizer.step()
            l.append(loss.item())
        train_l.append(np.mean(l))
        model.eval()
        l=[]
        for j,data1 in enumerate(validation_loader):
            x=data1[0].to(device)
            y=data1[1].to(device)
            att=data1[2].to(device)
            o,w=model(x,y,att,teacher_forcing_ratio=0)
            o = o.reshape(-1, o.shape[2]).to(device)
            y_orig = y.reshape(-1).to(device)
            loss = criterion(o, y_orig)
            l.append(loss.item())
        val_l.append(np.mean(l))
        print(f"epoch : {epoch} train_loss : {train_l[-1]} val_loss: {val_l[-1]} time taken : {(time.time()-st)/60}  ")
#         print("model saved!!")
#         torch.save(model, 'modelc_inloop.pth')
    return train_l,val_l
# Out:
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]

# %%
# import gc
# gc.collect()

# # Clear memory allocated by PyTorch
# torch.cuda.empty_cache()

# %%
train_l,val_l=train(40)
print("training completed")
# Out:
# =======================epoch 0================================
# epoch : 0 train_loss : 0.6138025201616749 val_loss: 1.3670819262240796 time taken : 3.250207789738973
# =======================epoch 1================================
# epoch : 1 train_loss : 0.4132270635135712 val_loss: 1.504035510915391 time taken : 6.492456551392873
# =======================epoch 2================================
# epoch : 2 train_loss : 0.3896816933587674 val_loss: 1.517240673937696 time taken : 9.730725026130676
# =======================epoch 3================================
# epoch : 3 train_loss : 0.3766568413184535 val_loss: 1.4907272876577173 time taken : 12.968724763393402
# =======================epoch 4================================
# epoch : 4 train_loss : 0.36404849632132436 val_loss: 1.438018316918231 time taken : 16.204140325387318
# =======================epoch 5================================
# epoch : 5 train_loss : 0.3553561058255934 val_loss: 1.4427542597689527 time taken : 19.43970971107483
# =======================epoch 6================================
# epoch : 6 train_loss : 0.3460872680189148 val_loss: 1.4359818265793172 time taken : 22.66841716368993
# =======================epoch 7================================
# epoch : 7 train_loss : 0.33935243037919843 val_loss: 1.4360903653692692 time taken : 25.903385174274444
# =======================epoch 8================================
# epoch : 8 train_loss : 0.33275113307660625 val_loss: 1.4062115296404412 time taken : 29.136480375130972
# =======================epoch 9================================
# epoch : 9 train_loss : 0.32802319175774053 val_loss: 1.2274815097768257 time taken : 32.36787475744883
# =======================epoch 10================================
# epoch : 10 train_loss : 0.3189257689781727 val_loss: 1.3130154279952353 time taken : 35.60132177670797
# =======================epoch 11================================
# epoch : 11 train_loss : 0.3142135304308707 val_loss: 1.2393703384602324 time taken : 38.828210429350534
# =======================epoch 12================================
# epoch : 12 train_loss : 0.3077527563898794 val_loss: 1.1817417487185051 time taken : 42.08036456505457
# =======================epoch 13================================
# epoch : 13 train_loss : 0.30122402036382306 val_loss: 1.1968808833588944 time taken : 45.30847072203954
# =======================epoch 14================================
# epoch : 14 train_loss : 0.2971303404819581 val_loss: 1.1470916106345805 time taken : 48.54120610555013
# =======================epoch 15================================
# epoch : 15 train_loss : 0.29105721666447576 val_loss: 1.0794184639098796 time taken : 51.77116719881693
# =======================epoch 16================================
# epoch : 16 train_loss : 0.28611156861147574 val_loss: 1.1258462413828423 time taken : 54.99994775056839
# =======================epoch 17================================
# epoch : 17 train_loss : 0.2805828458599506 val_loss: 1.105109306091958 time taken : 58.2298264781634
# =======================epoch 18================================
# epoch : 18 train_loss : 0.2784040004014969 val_loss: 1.0121792161718328 time taken : 61.45796292622884
# =======================epoch 19================================
# epoch : 19 train_loss : 0.2725749421984919 val_loss: 1.0309233196238254 time taken : 64.68604999780655
# =======================epoch 20================================
# epoch : 20 train_loss : 0.26737299172147627 val_loss: 0.993238996952138 time taken : 67.92248759667079
# =======================epoch 21================================
# epoch : 21 train_loss : 0.2640827097479374 val_loss: 1.0296398363214858 time taken : 71.15048053661982
# =======================epoch 22================================
# epoch : 22 train_loss : 0.25928609265435126 val_loss: 0.9947130210856174 time taken : 74.38853184382121
# =======================epoch 23================================
# epoch : 23 train_loss : 0.2553407729633393 val_loss: 0.9723966984038658 time taken : 77.62977701028188
# =======================epoch 24================================
# epoch : 24 train_loss : 0.2536466085141705 val_loss: 0.9903146421655695 time taken : 80.8742606719335
# =======================epoch 25================================
# epoch : 25 train_loss : 0.24864360214241088 val_loss: 0.9932859578031175 time taken : 84.11287733713786
# =======================epoch 26================================
# epoch : 26 train_loss : 0.2452104048863534 val_loss: 0.9405454891793271 time taken : 87.34461207787196
# =======================epoch 27================================
# epoch : 27 train_loss : 0.24057488970218166 val_loss: 0.9310982924826602 time taken : 90.57450009584427
# =======================epoch 28================================
# epoch : 28 train_loss : 0.2403415847209192 val_loss: 0.9396713781864086 time taken : 93.82180245320002
# =======================epoch 29================================
# epoch : 29 train_loss : 0.2361535291037252 val_loss: 0.9063604486749527 time taken : 97.06952237288156
# =======================epoch 30================================
# epoch : 30 train_loss : 0.23293096625035808 val_loss: 0.8689076520026998 time taken : 100.31840060949325
# =======================epoch 31================================
# epoch : 31 train_loss : 0.23139121929003345 val_loss: 0.8760137773574667 time taken : 103.55973721345266
# =======================epoch 32================================
# epoch : 32 train_loss : 0.22715621157999963 val_loss: 0.9210232959148732 time taken : 106.7887514869372
# =======================epoch 33================================
# epoch : 33 train_loss : 0.22729992705487437 val_loss: 0.8422078610734737 time taken : 110.03430695533753
# =======================epoch 34================================
# epoch : 34 train_loss : 0.2237435101261062 val_loss: 0.8702651008646539 time taken : 113.26298050085704
# =======================epoch 35================================
# epoch : 35 train_loss : 0.2211601058802297 val_loss: 0.8936043876282712 time taken : 116.48919282754262
# =======================epoch 36================================
# epoch : 36 train_loss : 0.21952778668172898 val_loss: 0.8202288575628971 time taken : 119.73134276866912
# =======================epoch 37================================
# epoch : 37 train_loss : 0.2186560886281152 val_loss: 0.8245362290676604 time taken : 122.95775218009949
# =======================epoch 38================================
# epoch : 38 train_loss : 0.2139118850471512 val_loss: 0.8310751724750438 time taken : 126.19896473089854
# =======================epoch 39================================
# epoch : 39 train_loss : 0.21377655539301135 val_loss: 0.8571217681499238 time taken : 129.42983050346373
# training completed

# %%
torch.save(model, 'modelc_final_40_epoch.pth')

# %%
import csv
def gen_csv(l,name):
    csv_file = name+".csv"
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Loss"])  # Write header
        for loss in l:
            writer.writerow([loss])
gen_csv(train_l,"train_loss_model3")
gen_csv(val_l,"val_loss_model3")
print("csv generated..")
# Out:
# csv generated..

# %% [markdown]
# # Beam

# %%
class BeamSearch3():
    def __init__(self, model,single_data,model_type, device,  max_target_len=80, beam_size=beam_size):
        self.model = model
        self.device = device
        self.start_token = pos_special_tokens_sol[0]
        self.en_ht = None
        self.en_ct = None
        self.encoder_out=None
        self.decoder_input_token=None
        self.max_target_len = max_target_len
        self.beam_size = beam_size
        self.single_data=single_data
        self.get_encoder_outputs(model_type)
        self.model_type=model_type
        self.beam = [([self.start_token], (self.en_ht, self.en_ct), 0)]


    def get_encoder_outputs(self,model_type):
        if(model_type==1 or model_type==2):
            x=self.single_data[0].to(device)
            self.encoder_out, (self.en_ht, self.en_ct) = self.model.lstm_encoder(x)

        elif(model_type==3 or model_type==4):
            src=self.single_data[0].to(device)
            src_mask=self.single_data[2].to(device)
            batch_size = src.shape[0]
            self.encoder_out = self.model.module.encoder(src, src_mask)
            self.en_ht = torch.zeros(1, batch_size, self.model.module.decoder.rnn.hidden_size).to(self.device)
            self.en_ct = torch.zeros(1, batch_size, self.model.module.decoder.rnn.hidden_size).to(self.device)
            

    def search(self):
        for _ in range(self.max_target_len - 1):
            self._expand_beam(self.model_type)
            self.beam.sort(key=lambda x: x[2])
            self.beam = self.beam[:self.beam_size]

        best_candidate = self.beam[0][0]
        decoded_words = self._construct_output(best_candidate)
        return decoded_words

    def _expand_beam(self,model_type):
        new_beam = []
        for sequence, (ht, ct), score in self.beam:
            prev_token = torch.LongTensor([sequence[-1]]).to(self.device)

            if(model_type==1):
                decoder_out, (ht, ct) = self.model.decoder(prev_token, (ht, ct))
            elif(model_type==2):
                decoder_out, (ht, ct) = self.model.lstm_decoder(prev_token, (ht, ct),self.encoder_out)
            elif(model_type==3 or model_type==4):
                decoder_out, ht, ct= self.model.module.decoder(prev_token, ht, ct,self.encoder_out)

            decoder_out = decoder_out.squeeze(1)
            top_vals, top_inds = decoder_out.topk(self.beam_size, dim=1)

            self._add_candidates(new_beam, sequence, ht, ct, score, top_vals, top_inds)

        self.beam = new_beam

    def _add_candidates(self, new_beam, sequence, ht, ct, score, top_vals, top_inds):
        for j in range(self.beam_size):
            new_word_idx = top_inds[0][j]
            new_seq = sequence + [new_word_idx.item()]
            new_word_prob = torch.log(top_vals[0][j])
            updated_score = score - new_word_prob
            new_candidate = (new_seq, (ht, ct), updated_score)
            new_beam.append(new_candidate)

    def _construct_output(self, best_candidate):
        decoded_words = torch.zeros(1, self.max_target_len)
        for t, idx in enumerate(best_candidate):
            decoded_words[:, t] = torch.LongTensor([idx])
        return decoded_words

# %%
def generate_csv(model,data,loader):
    model.eval()
    prediction=[]
    for batch in loader:
        x=batch[0].to(device)
        y=batch[1].to(device)
        o,w=model(x,y,tf=0)
        prediction.append(w)
    predicted_data_strings=[]
    for batch in prediction:
        for one_data in batch:
            one_data=one_data.to(torch.int)
            one_data_in_string=""
            conv_int_word=[]
            for pos,value in enumerate(one_data):
                conv_int_word.append(data.sol_int2word[value.item()])
            predicted_data_strings.append(conv_int_word)
    return predicted_data_strings

# %%
def extract_sol(data2str):
    complete_data=[]
    for each_data in data2str:
        s=""
        flag=0
        for item in each_data[1:]:
            if(item=="<eos>" or item=="<pad>"):
                complete_data.append(s)
                flag=1
                break
            else:
                s+=str(item)
        if(flag==0):
            complete_data.append(s)
    return complete_data

# %%
def generate_sol(int2data,name,data_name):
    json_data=[]
    for k,s in zip(data_name.data,int2data):
        d={
            "Problem":k[0],
            "answer":k[2],
            "predicted":s,
            "linear_formula":k[1]
        }
        json_data.append(d)
    with open(str(name)+".json", 'w') as json_file:
        json.dump(json_data, json_file,indent=4)
    print("prediction json generated!!")

# %%
def convtostr(prediction,data):
    predicted_data_strings=[]
    for batch in prediction:
        for one_data in batch:
            one_data=one_data.to(torch.int)
            one_data_in_string=""
            conv_int_word=[]
            for pos,value in enumerate(one_data):
                conv_int_word.append(data.sol_int2word[value.item()])
            predicted_data_strings.append(conv_int_word)
    return predicted_data_strings

# %%
def get_me_final_file(op_test,data,file_name):
    prediction_in_str=convtostr(op_test,data)
    good=extract_sol(prediction_in_str)
    generate_sol(good,file_name,data)

# %%
op_test=[]
for i,one_data in enumerate(validation_loader1):
    beam=BeamSearch3(model=model,single_data=one_data,model_type=3, device=device,  max_target_len=300, beam_size=10)
    op_test.append(beam.search())
    print(f"{i}th data completed")
get_me_final_file(op_test,val_data,"valid_beam_modelC")
op_test=[]
for i,one_data in enumerate(test_loader):
    beam=BeamSearch3(model=model,single_data=one_data,model_type=3, device=device,  max_target_len=300, beam_size=10)
    op_test.append(beam.search())
    print(f"{i}th data completed")
get_me_final_file(op_test,test_data,"test_beam_modelC")
# Out:
# 0th data completed
# 1th data completed
# 2th data completed
# 3th data completed
# 4th data completed
# 5th data completed
# 6th data completed
# 7th data completed
# 8th data completed
# 9th data completed
# 10th data completed
# 11th data completed
# 12th data completed
# 13th data completed
# 14th data completed
# 15th data completed
# 16th data completed
# 17th data completed
# 18th data completed
# 19th data completed
# 20th data completed
# 21th data completed
# 22th data completed
# 23th data completed
# 24th data completed
# 25th data completed
# 26th data completed
# 27th data completed
# 28th data completed
# 29th data completed
# 30th data completed
# 31th data completed
# 32th data completed
# 33th data completed
# 34th data completed
# 35th data completed
# 36th data completed
# 37th data completed
# 38th data completed
# 39th data completed
# 40th data completed
# 41th data completed
# 42th data completed
# 43th data completed
# 44th data completed
# 45th data completed
# 46th data completed
# 47th data completed
# 48th data completed
# 49th data completed
# 50th data completed
# 51th data completed
# 52th data completed
# 53th data completed
# 54th data completed
# 55th data completed
# 56th data completed
# 57th data completed
# 58th data completed
# 59th data completed
# 60th data completed
# 61th data completed
# 62th data completed
# 63th data completed
# 64th data completed
# 65th data completed
# 66th data completed
# 67th data completed
# 68th data completed
# 69th data completed
# 70th data completed
# 71th data completed
# 72th data completed
# 73th data completed
# 74th data completed
# 75th data completed
# 76th data completed
# 77th data completed
# 78th data completed
# 79th data completed
# 80th data completed
# 81th data completed
# 82th data completed
# 83th data completed
# 84th data completed
# 85th data completed
# 86th data completed
# 87th data completed
# 88th data completed
# 89th data completed
# 90th data completed
# 91th data completed
# 92th data completed
# 93th data completed
# 94th data completed
# 95th data completed
# 96th data completed
# 97th data completed
# 98th data completed
# 99th data completed
# 100th data completed
# 101th data completed
# 102th data completed
# 103th data completed
# 104th data completed
# 105th data completed
# 106th data completed
# 107th data completed
# 108th data completed
# 109th data completed
# 110th data completed
# 111th data completed
# 112th data completed
# 113th data completed
# 114th data completed
# 115th data completed
# 116th data completed
# 117th data completed
# 118th data completed
# 119th data completed
# 120th data completed
# 121th data completed
# 122th data completed
# 123th data completed
# 124th data completed
# 125th data completed
# 126th data completed
# 127th data completed
# 128th data completed
# 129th data completed
# 130th data completed
# 131th data completed
# 132th data completed
# 133th data completed
# 134th data completed
# 135th data completed
# 136th data completed
# 137th data completed
# 138th data completed
# 139th data completed
# 140th data completed
# 141th data completed
# 142th data completed
# 143th data completed
# 144th data completed
# 145th data completed
# 146th data completed
# 147th data completed
# 148th data completed
# 149th data completed
# 150th data completed
# 151th data completed
# 152th data completed
# 153th data completed
# 154th data completed
# 155th data completed
# 156th data completed
# 157th data completed
# 158th data completed
# 159th data completed
# 160th data completed
# 161th data completed
# 162th data completed
# 163th data completed
# 164th data completed
# 165th data completed
# 166th data completed
# 167th data completed
# 168th data completed
# 169th data completed
# 170th data completed
# 171th data completed
# 172th data completed
# 173th data completed
# 174th data completed
# 175th data completed
# 176th data completed
# 177th data completed
# 178th data completed
# 179th data completed
# 180th data completed
# 181th data completed
# 182th data completed
# 183th data completed
# 184th data completed
# 185th data completed
# 186th data completed
# 187th data completed
# 188th data completed
# 189th data completed
# 190th data completed
# 191th data completed
# 192th data completed
# 193th data completed
# 194th data completed
# 195th data completed
# 196th data completed
# 197th data completed
# 198th data completed
# 199th data completed
# 200th data completed
# 201th data completed
# 202th data completed
# 203th data completed
# 204th data completed
# 205th data completed
# 206th data completed
# 207th data completed
# 208th data completed
# 209th data completed
# 210th data completed
# 211th data completed
# 212th data completed
# 213th data completed
# 214th data completed
# 215th data completed
# 216th data completed
# 217th data completed
# 218th data completed
# 219th data completed
# 220th data completed
# 221th data completed
# 222th data completed
# 223th data completed
# 224th data completed
# 225th data completed
# 226th data completed
# 227th data completed
# 228th data completed
# 229th data completed
# 230th data completed
# 231th data completed
# 232th data completed
# 233th data completed
# 234th data completed
# 235th data completed
# 236th data completed
# 237th data completed
# 238th data completed
# 239th data completed
# 240th data completed
# 241th data completed
# 242th data completed
# 243th data completed
# 244th data completed
# 245th data completed
# 246th data completed
# 247th data completed
# 248th data completed
# 249th data completed
# 250th data completed
# 251th data completed
# 252th data completed
# 253th data completed
# 254th data completed
# 255th data completed
# 256th data completed
# 257th data completed
# 258th data completed
# 259th data completed
# 260th data completed
# 261th data completed
# 262th data completed
# 263th data completed
# 264th data completed
# 265th data completed
# 266th data completed
# 267th data completed
# 268th data completed
# 269th data completed
# 270th data completed
# 271th data completed
# 272th data completed
# 273th data completed
# 274th data completed
# 275th data completed
# 276th data completed
# 277th data completed
# 278th data completed
# 279th data completed
# 280th data completed
# 281th data completed
# 282th data completed
# 283th data completed
# 284th data completed
# 285th data completed
# 286th data completed
# 287th data completed
# 288th data completed
# 289th data completed
# 290th data completed
# 291th data completed
# 292th data completed
# 293th data completed
# 294th data completed
# 295th data completed
# 296th data completed
# 297th data completed
# 298th data completed
# 299th data completed
# 300th data completed
# 301th data completed
# 302th data completed
# 303th data completed
# 304th data completed
# 305th data completed
# 306th data completed
# 307th data completed
# 308th data completed
# 309th data completed
# 310th data completed
# 311th data completed
# 312th data completed
# 313th data completed
# 314th data completed
# 315th data completed
# 316th data completed
# 317th data completed
# 318th data completed
# 319th data completed
# 320th data completed
# 321th data completed
# 322th data completed
# 323th data completed
# 324th data completed
# 325th data completed
# 326th data completed
# 327th data completed
# 328th data completed
# 329th data completed
# 330th data completed
# 331th data completed
# 332th data completed
# 333th data completed
# 334th data completed
# 335th data completed
# 336th data completed
# 337th data completed
# 338th data completed
# 339th data completed
# 340th data completed
# 341th data completed
# 342th data completed
# 343th data completed
# 344th data completed
# 345th data completed
# 346th data completed
# 347th data completed
# 348th data completed
# 349th data completed
# 350th data completed
# 351th data completed
# 352th data completed
# 353th data completed
# 354th data completed
# 355th data completed
# 356th data completed
# 357th data completed
# 358th data completed
# 359th data completed
# 360th data completed
# 361th data completed
# 362th data completed
# 363th data completed
# 364th data completed
# 365th data completed
# 366th data completed
# 367th data completed
# 368th data completed
# 369th data completed
# 370th data completed
# 371th data completed
# 372th data completed
# 373th data completed
# 374th data completed
# 375th data completed
# 376th data completed
# 377th data completed
# 378th data completed
# 379th data completed
# 380th data completed
# 381th data completed
# 382th data completed
# 383th data completed
# 384th data completed
# 385th data completed
# 386th data completed
# 387th data completed
# 388th data completed
# 389th data completed
# 390th data completed
# 391th data completed
# 392th data completed
# 393th data completed
# 394th data completed
# 395th data completed
# 396th data completed
# 397th data completed
# 398th data completed
# 399th data completed
# 400th data completed
# 401th data completed
# 402th data completed
# 403th data completed
# 404th data completed
# 405th data completed
# 406th data completed
# 407th data completed
# 408th data completed
# 409th data completed
# 410th data completed
# 411th data completed
# 412th data completed
# 413th data completed
# 414th data completed
# 415th data completed
# 416th data completed
# 417th data completed
# 418th data completed
# 419th data completed
# 420th data completed
# 421th data completed
# 422th data completed
# 423th data completed
# 424th data completed
# 425th data completed
# 426th data completed
# 427th data completed
# 428th data completed
# 429th data completed
# 430th data completed
# 431th data completed
# 432th data completed
# 433th data completed
# 434th data completed
# 435th data completed
# 436th data completed
# 437th data completed
# 438th data completed
# 439th data completed
# 440th data completed
# 441th data completed
# 442th data completed
# 443th data completed
# 444th data completed
# 445th data completed
# 446th data completed
# 447th data completed
# 448th data completed
# 449th data completed
# 450th data completed
# 451th data completed
# 452th data completed
# 453th data completed
# 454th data completed
# 455th data completed
# 456th data completed
# 457th data completed
# 458th data completed
# 459th data completed
# 460th data completed
# 461th data completed
# 462th data completed
# 463th data completed
# 464th data completed
# 465th data completed
# 466th data completed
# 467th data completed
# 468th data completed
# 469th data completed
# 470th data completed
# 471th data completed
# 472th data completed
# 473th data completed
# 474th data completed
# 475th data completed
# 476th data completed
# 477th data completed
# 478th data completed
# 479th data completed
# 480th data completed
# 481th data completed
# 482th data completed
# 483th data completed
# 484th data completed
# 485th data completed
# 486th data completed
# 487th data completed
# 488th data completed
# 489th data completed
# 490th data completed
# 491th data completed
# 492th data completed
# 493th data completed
# 494th data completed
# 495th data completed
# 496th data completed
# 497th data completed
# 498th data completed
# 499th data completed
# 500th data completed
# 501th data completed
# 502th data completed
# 503th data completed
# 504th data completed
# 505th data completed
# 506th data completed
# 507th data completed
# 508th data completed
# 509th data completed
# 510th data completed
# 511th data completed
# 512th data completed
# 513th data completed
# 514th data completed
# 515th data completed
# 516th data completed
# 517th data completed
# 518th data completed
# 519th data completed
# 520th data completed
# 521th data completed
# 522th data completed
# 523th data completed
# 524th data completed
# 525th data completed
# 526th data completed
# 527th data completed
# 528th data completed
# 529th data completed
# 530th data completed
# 531th data completed
# 532th data completed
# 533th data completed
# 534th data completed
# 535th data completed
# 536th data completed
# 537th data completed
# 538th data completed
# 539th data completed
# 540th data completed
# 541th data completed
# 542th data completed
# 543th data completed
# 544th data completed
# 545th data completed
# 546th data completed
# 547th data completed
# 548th data completed
# 549th data completed
# 550th data completed
# 551th data completed
# 552th data completed
# 553th data completed
# 554th data completed
# 555th data completed
# 556th data completed
# 557th data completed
# 558th data completed
# 559th data completed
# 560th data completed
# 561th data completed
# 562th data completed
# 563th data completed
# 564th data completed
# 565th data completed
# 566th data completed
# 567th data completed
# 568th data completed
# 569th data completed
# 570th data completed
# 571th data completed
# 572th data completed
# 573th data completed
# 574th data completed
# 575th data completed
# 576th data completed
# 577th data completed
# 578th data completed
# 579th data completed
# 580th data completed
# 581th data completed
# 582th data completed
# 583th data completed
# 584th data completed
# 585th data completed
# 586th data completed
# 587th data completed
# 588th data completed
# 589th data completed
# 590th data completed
# 591th data completed
# 592th data completed
# 593th data completed
# 594th data completed
# 595th data completed
# 596th data completed
# 597th data completed
# 598th data completed
# 599th data completed
# 600th data completed
# 601th data completed
# 602th data completed
# 603th data completed
# 604th data completed
# 605th data completed
# 606th data completed
# 607th data completed
# 608th data completed
# 609th data completed
# 610th data completed
# 611th data completed
# 612th data completed
# 613th data completed
# 614th data completed
# 615th data completed
# 616th data completed
# 617th data completed
# 618th data completed
# 619th data completed
# 620th data completed
# 621th data completed
# 622th data completed
# 623th data completed
# 624th data completed
# 625th data completed
# 626th data completed
# 627th data completed
# 628th data completed
# 629th data completed
# 630th data completed
# 631th data completed
# 632th data completed
# 633th data completed
# 634th data completed
# 635th data completed
# 636th data completed
# 637th data completed
# 638th data completed
# 639th data completed
# 640th data completed
# 641th data completed
# 642th data completed
# 643th data completed
# 644th data completed
# 645th data completed
# 646th data completed
# 647th data completed
# 648th data completed
# 649th data completed
# 650th data completed
# 651th data completed
# 652th data completed
# 653th data completed
# 654th data completed
# 655th data completed
# 656th data completed
# 657th data completed
# 658th data completed
# 659th data completed
# 660th data completed
# 661th data completed
# 662th data completed
# 663th data completed
# 664th data completed
# 665th data completed
# 666th data completed
# 667th data completed
# 668th data completed
# 669th data completed
# 670th data completed
# 671th data completed
# 672th data completed
# 673th data completed
# 674th data completed
# 675th data completed
# 676th data completed
# 677th data completed
# 678th data completed
# 679th data completed
# 680th data completed
# 681th data completed
# 682th data completed
# 683th data completed
# 684th data completed
# 685th data completed
# 686th data completed
# 687th data completed
# 688th data completed
# 689th data completed
# 690th data completed
# 691th data completed
# 692th data completed
# 693th data completed
# 694th data completed
# 695th data completed
# 696th data completed
# 697th data completed
# 698th data completed
# 699th data completed
# 700th data completed
# 701th data completed
# 702th data completed
# 703th data completed
# 704th data completed
# 705th data completed
# 706th data completed
# 707th data completed
# 708th data completed
# 709th data completed
# 710th data completed
# 711th data completed
# 712th data completed
# 713th data completed
# 714th data completed
# 715th data completed
# 716th data completed
# 717th data completed
# 718th data completed
# 719th data completed
# 720th data completed
# 721th data completed
# 722th data completed
# 723th data completed
# 724th data completed
# 725th data completed
# 726th data completed
# 727th data completed
# 728th data completed
# 729th data completed
# 730th data completed
# 731th data completed
# 732th data completed
# 733th data completed
# 734th data completed
# 735th data completed
# 736th data completed
# 737th data completed
# 738th data completed
# 739th data completed
# 740th data completed
# 741th data completed
# 742th data completed
# 743th data completed
# 744th data completed
# 745th data completed
# 746th data completed
# 747th data completed
# 748th data completed
# 749th data completed
# 750th data completed
# 751th data completed
# 752th data completed
# 753th data completed
# 754th data completed
# 755th data completed
# 756th data completed
# 757th data completed
# 758th data completed
# 759th data completed
# 760th data completed
# 761th data completed
# 762th data completed
# 763th data completed
# 764th data completed
# 765th data completed
# 766th data completed
# 767th data completed
# 768th data completed
# 769th data completed
# 770th data completed
# 771th data completed
# 772th data completed
# 773th data completed
# 774th data completed
# 775th data completed
# 776th data completed
# 777th data completed
# 778th data completed
# 779th data completed
# 780th data completed
# 781th data completed
# 782th data completed
# 783th data completed
# 784th data completed
# 785th data completed
# 786th data completed
# 787th data completed
# 788th data completed
# 789th data completed
# 790th data completed
# 791th data completed
# 792th data completed
# 793th data completed
# 794th data completed
# 795th data completed
# 796th data completed
# 797th data completed
# 798th data completed
# 799th data completed
# 800th data completed
# 801th data completed
# 802th data completed
# 803th data completed
# 804th data completed
# 805th data completed
# 806th data completed
# 807th data completed
# 808th data completed
# 809th data completed
# 810th data completed
# 811th data completed
# 812th data completed
# 813th data completed
# 814th data completed
# 815th data completed
# 816th data completed
# 817th data completed
# 818th data completed
# 819th data completed
# 820th data completed
# 821th data completed
# 822th data completed
# 823th data completed
# 824th data completed
# 825th data completed
# 826th data completed
# 827th data completed
# 828th data completed
# 829th data completed
# 830th data completed
# 831th data completed
# 832th data completed
# 833th data completed
# 834th data completed
# 835th data completed
# 836th data completed
# 837th data completed
# 838th data completed
# 839th data completed
# 840th data completed
# 841th data completed
# 842th data completed
# 843th data completed
# 844th data completed
# 845th data completed
# 846th data completed
# 847th data completed
# 848th data completed
# 849th data completed
# 850th data completed
# 851th data completed
# 852th data completed
# 853th data completed
# 854th data completed
# 855th data completed
# 856th data completed
# 857th data completed
# 858th data completed
# 859th data completed
# 860th data completed
# 861th data completed
# 862th data completed
# 863th data completed
# 864th data completed
# 865th data completed
# 866th data completed
# 867th data completed
# 868th data completed
# 869th data completed
# 870th data completed
# 871th data completed
# 872th data completed
# 873th data completed
# 874th data completed
# 875th data completed
# 876th data completed
# 877th data completed
# 878th data completed
# 879th data completed
# 880th data completed
# 881th data completed
# 882th data completed
# 883th data completed
# 884th data completed
# 885th data completed
# 886th data completed
# 887th data completed
# 888th data completed
# 889th data completed
# 890th data completed
# 891th data completed
# 892th data completed
# 893th data completed
# 894th data completed
# 895th data completed
# 896th data completed
# 897th data completed
# 898th data completed
# 899th data completed
# 900th data completed
# 901th data completed
# 902th data completed
# 903th data completed
# 904th data completed
# 905th data completed
# 906th data completed
# 907th data completed
# 908th data completed
# 909th data completed
# 910th data completed
# 911th data completed
# 912th data completed
# 913th data completed
# 914th data completed
# 915th data completed
# 916th data completed
# 917th data completed
# 918th data completed
# 919th data completed
# 920th data completed
# 921th data completed
# 922th data completed
# 923th data completed
# 924th data completed
# 925th data completed
# 926th data completed
# 927th data completed
# 928th data completed
# 929th data completed
# 930th data completed
# 931th data completed
# 932th data completed
# 933th data completed
# 934th data completed
# 935th data completed
# 936th data completed
# 937th data completed
# 938th data completed
# 939th data completed
# 940th data completed
# 941th data completed
# 942th data completed
# 943th data completed
# 944th data completed
# 945th data completed
# 946th data completed
# 947th data completed
# 948th data completed
# 949th data completed
# 950th data completed
# 951th data completed
# 952th data completed
# 953th data completed
# 954th data completed
# 955th data completed
# 956th data completed
# 957th data completed
# 958th data completed
# 959th data completed
# 960th data completed
# 961th data completed
# 962th data completed
# 963th data completed
# 964th data completed
# 965th data completed
# 966th data completed
# 967th data completed
# 968th data completed
# 969th data completed
# 970th data completed
# 971th data completed
# 972th data completed
# 973th data completed
# 974th data completed
# 975th data completed
# 976th data completed
# 977th data completed
# 978th data completed
# 979th data completed
# 980th data completed
# 981th data completed
# 982th data completed
# 983th data completed
# 984th data completed
# 985th data completed
# 986th data completed
# 987th data completed
# 988th data completed
# 989th data completed
# 990th data completed
# 991th data completed
# 992th data completed
# 993th data completed
# 994th data completed
# 995th data completed
# 996th data completed
# 997th data completed
# 998th data completed
# 999th data completed
# 1000th data completed
# 1001th data completed
# 1002th data completed
# 1003th data completed
# 1004th data completed
# 1005th data completed
# 1006th data completed
# 1007th data completed
# 1008th data completed
# 1009th data completed
# 1010th data completed
# 1011th data completed
# 1012th data completed
# 1013th data completed
# 1014th data completed
# 1015th data completed
# 1016th data completed
# 1017th data completed
# 1018th data completed
# 1019th data completed
# 1020th data completed
# 1021th data completed
# 1022th data completed
# 1023th data completed
# 1024th data completed
# 1025th data completed
# 1026th data completed
# 1027th data completed
# 1028th data completed
# 1029th data completed
# 1030th data completed
# 1031th data completed
# 1032th data completed
# 1033th data completed
# 1034th data completed
# 1035th data completed
# 1036th data completed
# 1037th data completed
# 1038th data completed
# 1039th data completed
# 1040th data completed
# 1041th data completed
# 1042th data completed
# 1043th data completed
# 1044th data completed
# 1045th data completed
# 1046th data completed
# 1047th data completed
# 1048th data completed
# 1049th data completed
# 1050th data completed
# 1051th data completed
# 1052th data completed
# 1053th data completed
# 1054th data completed
# 1055th data completed
# 1056th data completed
# 1057th data completed
# 1058th data completed
# 1059th data completed
# 1060th data completed
# 1061th data completed
# 1062th data completed
# 1063th data completed
# 1064th data completed
# 1065th data completed
# 1066th data completed
# 1067th data completed
# 1068th data completed
# 1069th data completed
# 1070th data completed
# 1071th data completed
# 1072th data completed
# 1073th data completed
# 1074th data completed
# 1075th data completed
# 1076th data completed
# 1077th data completed
# 1078th data completed
# 1079th data completed
# 1080th data completed
# 1081th data completed
# 1082th data completed
# 1083th data completed
# 1084th data completed
# 1085th data completed
# 1086th data completed
# 1087th data completed
# 1088th data completed
# 1089th data completed
# 1090th data completed
# 1091th data completed
# 1092th data completed
# 1093th data completed
# 1094th data completed
# 1095th data completed
# 1096th data completed
# 1097th data completed
# 1098th data completed
# 1099th data completed
# 1100th data completed
# 1101th data completed
# 1102th data completed
# 1103th data completed
# 1104th data completed
# 1105th data completed
# 1106th data completed
# 1107th data completed
# 1108th data completed
# 1109th data completed
# 1110th data completed
# 1111th data completed
# 1112th data completed
# 1113th data completed
# 1114th data completed
# 1115th data completed
# 1116th data completed
# 1117th data completed
# 1118th data completed
# 1119th data completed
# 1120th data completed
# 1121th data completed
# 1122th data completed
# 1123th data completed
# 1124th data completed
# 1125th data completed
# 1126th data completed
# 1127th data completed
# 1128th data completed
# 1129th data completed
# 1130th data completed
# 1131th data completed
# 1132th data completed
# 1133th data completed
# 1134th data completed
# 1135th data completed
# 1136th data completed
# 1137th data completed
# 1138th data completed
# 1139th data completed
# 1140th data completed
# 1141th data completed
# 1142th data completed
# 1143th data completed
# 1144th data completed
# 1145th data completed
# 1146th data completed
# 1147th data completed
# 1148th data completed
# 1149th data completed
# 1150th data completed
# 1151th data completed
# 1152th data completed
# 1153th data completed
# 1154th data completed
# 1155th data completed
# 1156th data completed
# 1157th data completed
# 1158th data completed
# 1159th data completed
# 1160th data completed
# 1161th data completed
# 1162th data completed
# 1163th data completed
# 1164th data completed
# 1165th data completed
# 1166th data completed
# 1167th data completed
# 1168th data completed
# 1169th data completed
# 1170th data completed
# 1171th data completed
# 1172th data completed
# 1173th data completed
# 1174th data completed
# 1175th data completed
# 1176th data completed
# 1177th data completed
# 1178th data completed
# 1179th data completed
# 1180th data completed
# 1181th data completed
# 1182th data completed
# 1183th data completed
# 1184th data completed
# 1185th data completed
# 1186th data completed
# 1187th data completed
# 1188th data completed
# 1189th data completed
# 1190th data completed
# 1191th data completed
# 1192th data completed
# 1193th data completed
# 1194th data completed
# 1195th data completed
# 1196th data completed
# 1197th data completed
# 1198th data completed
# 1199th data completed
# 1200th data completed
# 1201th data completed
# 1202th data completed
# 1203th data completed
# 1204th data completed
# 1205th data completed
# 1206th data completed
# 1207th data completed
# 1208th data completed
# 1209th data completed
# 1210th data completed
# 1211th data completed
# 1212th data completed
# 1213th data completed
# 1214th data completed
# 1215th data completed
# 1216th data completed
# 1217th data completed
# 1218th data completed
# 1219th data completed
# 1220th data completed
# 1221th data completed
# 1222th data completed
# 1223th data completed
# 1224th data completed
# 1225th data completed
# 1226th data completed
# 1227th data completed
# 1228th data completed
# 1229th data completed
# 1230th data completed
# 1231th data completed
# 1232th data completed
# 1233th data completed
# 1234th data completed
# 1235th data completed
# 1236th data completed
# 1237th data completed
# 1238th data completed
# 1239th data completed
# 1240th data completed
# 1241th data completed
# 1242th data completed
# 1243th data completed
# 1244th data completed
# 1245th data completed
# 1246th data completed
# 1247th data completed
# 1248th data completed
# 1249th data completed
# 1250th data completed
# 1251th data completed
# 1252th data completed
# 1253th data completed
# 1254th data completed
# 1255th data completed
# 1256th data completed
# 1257th data completed
# 1258th data completed
# 1259th data completed
# 1260th data completed
# 1261th data completed
# 1262th data completed
# 1263th data completed
# 1264th data completed
# 1265th data completed
# 1266th data completed
# 1267th data completed
# 1268th data completed
# 1269th data completed
# 1270th data completed
# 1271th data completed
# 1272th data completed
# 1273th data completed
# 1274th data completed
# 1275th data completed
# 1276th data completed
# 1277th data completed
# 1278th data completed
# 1279th data completed
# 1280th data completed
# 1281th data completed
# 1282th data completed
# 1283th data completed
# 1284th data completed
# 1285th data completed
# 1286th data completed
# 1287th data completed
# 1288th data completed
# 1289th data completed
# 1290th data completed
# 1291th data completed
# 1292th data completed
# 1293th data completed
# 1294th data completed
# 1295th data completed
# 1296th data completed
# 1297th data completed
# 1298th data completed
# 1299th data completed
# 1300th data completed
# 1301th data completed
# 1302th data completed
# 1303th data completed
# 1304th data completed
# 1305th data completed
# 1306th data completed
# 1307th data completed
# 1308th data completed
# 1309th data completed
# 1310th data completed
# 1311th data completed
# 1312th data completed
# 1313th data completed
# 1314th data completed
# 1315th data completed
# 1316th data completed
# 1317th data completed
# 1318th data completed
# 1319th data completed
# 1320th data completed
# 1321th data completed
# 1322th data completed
# 1323th data completed
# 1324th data completed
# 1325th data completed
# 1326th data completed
# 1327th data completed
# 1328th data completed
# 1329th data completed
# 1330th data completed
# 1331th data completed
# 1332th data completed
# 1333th data completed
# 1334th data completed
# 1335th data completed
# 1336th data completed
# 1337th data completed
# 1338th data completed
# 1339th data completed
# 1340th data completed
# 1341th data completed
# 1342th data completed
# 1343th data completed
# 1344th data completed
# 1345th data completed
# 1346th data completed
# 1347th data completed
# 1348th data completed
# 1349th data completed
# 1350th data completed
# 1351th data completed
# 1352th data completed
# 1353th data completed
# 1354th data completed
# 1355th data completed
# 1356th data completed
# 1357th data completed
# 1358th data completed
# 1359th data completed
# 1360th data completed
# 1361th data completed
# 1362th data completed
# 1363th data completed
# 1364th data completed
# 1365th data completed
# 1366th data completed
# 1367th data completed
# 1368th data completed
# 1369th data completed
# 1370th data completed
# 1371th data completed
# 1372th data completed
# 1373th data completed
# 1374th data completed
# 1375th data completed
# 1376th data completed
# 1377th data completed
# 1378th data completed
# 1379th data completed
# 1380th data completed
# 1381th data completed
# 1382th data completed
# 1383th data completed
# 1384th data completed
# 1385th data completed
# 1386th data completed
# 1387th data completed
# 1388th data completed
# 1389th data completed
# 1390th data completed
# 1391th data completed
# 1392th data completed
# 1393th data completed
# 1394th data completed
# 1395th data completed
# 1396th data completed
# 1397th data completed
# 1398th data completed
# 1399th data completed
# 1400th data completed
# 1401th data completed
# 1402th data completed
# 1403th data completed
# 1404th data completed
# 1405th data completed
# 1406th data completed
# 1407th data completed
# 1408th data completed
# 1409th data completed
# 1410th data completed
# 1411th data completed
# 1412th data completed
# 1413th data completed
# 1414th data completed
# 1415th data completed
# 1416th data completed
# 1417th data completed
# 1418th data completed
# 1419th data completed
# 1420th data completed
# 1421th data completed
# 1422th data completed
# 1423th data completed
# 1424th data completed
# 1425th data completed
# 1426th data completed
# 1427th data completed
# 1428th data completed
# 1429th data completed
# 1430th data completed
# 1431th data completed
# 1432th data completed
# 1433th data completed
# 1434th data completed
# 1435th data completed
# 1436th data completed
# 1437th data completed
# 1438th data completed
# 1439th data completed
# 1440th data completed
# 1441th data completed
# 1442th data completed
# 1443th data completed
# 1444th data completed
# 1445th data completed
# 1446th data completed
# 1447th data completed
# 1448th data completed
# 1449th data completed
# 1450th data completed
# 1451th data completed
# 1452th data completed
# 1453th data completed
# 1454th data completed
# 1455th data completed
# 1456th data completed
# 1457th data completed
# 1458th data completed
# 1459th data completed
# 1460th data completed
# 1461th data completed
# 1462th data completed
# 1463th data completed
# 1464th data completed
# 1465th data completed
# 1466th data completed
# 1467th data completed
# 1468th data completed
# 1469th data completed
# 1470th data completed
# 1471th data completed
# 1472th data completed
# 1473th data completed
# 1474th data completed
# 1475th data completed
# 1476th data completed
# 1477th data completed
# 1478th data completed
# 1479th data completed
# 1480th data completed
# 1481th data completed
# 1482th data completed
# 1483th data completed
# 1484th data completed
# 1485th data completed
# 1486th data completed
# 1487th data completed
# 1488th data completed
# 1489th data completed
# 1490th data completed
# 1491th data completed
# 1492th data completed
# 1493th data completed
# 1494th data completed
# 1495th data completed
# 1496th data completed
# 1497th data completed
# 1498th data completed
# 1499th data completed
# 1500th data completed
# 1501th data completed
# 1502th data completed
# 1503th data completed
# 1504th data completed
# 1505th data completed
# 1506th data completed
# 1507th data completed
# 1508th data completed
# 1509th data completed
# 1510th data completed
# 1511th data completed
# 1512th data completed
# 1513th data completed
# 1514th data completed
# 1515th data completed
# 1516th data completed
# 1517th data completed
# 1518th data completed
# 1519th data completed
# 1520th data completed
# 1521th data completed
# 1522th data completed
# 1523th data completed
# 1524th data completed
# 1525th data completed
# 1526th data completed
# 1527th data completed
# 1528th data completed
# 1529th data completed
# 1530th data completed
# 1531th data completed
# 1532th data completed
# 1533th data completed
# 1534th data completed
# 1535th data completed
# 1536th data completed
# 1537th data completed
# 1538th data completed
# 1539th data completed
# 1540th data completed
# 1541th data completed
# 1542th data completed
# 1543th data completed
# 1544th data completed
# 1545th data completed
# 1546th data completed
# 1547th data completed
# 1548th data completed
# 1549th data completed
# 1550th data completed
# 1551th data completed
# 1552th data completed
# 1553th data completed
# 1554th data completed
# 1555th data completed
# 1556th data completed
# 1557th data completed
# 1558th data completed
# 1559th data completed
# 1560th data completed
# 1561th data completed
# 1562th data completed
# 1563th data completed
# 1564th data completed
# 1565th data completed
# 1566th data completed
# 1567th data completed
# 1568th data completed
# 1569th data completed
# 1570th data completed
# 1571th data completed
# 1572th data completed
# 1573th data completed
# 1574th data completed
# 1575th data completed
# 1576th data completed
# 1577th data completed
# 1578th data completed
# 1579th data completed
# 1580th data completed
# 1581th data completed
# 1582th data completed
# 1583th data completed
# 1584th data completed
# 1585th data completed
# 1586th data completed
# 1587th data completed
# 1588th data completed
# 1589th data completed
# 1590th data completed
# 1591th data completed
# 1592th data completed
# 1593th data completed
# 1594th data completed
# 1595th data completed
# 1596th data completed
# 1597th data completed
# 1598th data completed
# 1599th data completed
# 1600th data completed
# 1601th data completed
# 1602th data completed
# 1603th data completed
# 1604th data completed
# 1605th data completed
# 1606th data completed
# 1607th data completed
# 1608th data completed
# 1609th data completed
# 1610th data completed
# 1611th data completed
# 1612th data completed
# 1613th data completed
# 1614th data completed
# 1615th data completed
# 1616th data completed
# 1617th data completed
# 1618th data completed
# 1619th data completed
# 1620th data completed
# 1621th data completed
# 1622th data completed
# 1623th data completed
# 1624th data completed
# 1625th data completed
# 1626th data completed
# 1627th data completed
# 1628th data completed
# 1629th data completed
# 1630th data completed
# 1631th data completed
# 1632th data completed
# 1633th data completed
# 1634th data completed
# 1635th data completed
# 1636th data completed
# 1637th data completed
# 1638th data completed
# 1639th data completed
# 1640th data completed
# 1641th data completed
# 1642th data completed
# 1643th data completed
# 1644th data completed
# 1645th data completed
# 1646th data completed
# 1647th data completed
# 1648th data completed
# 1649th data completed
# 1650th data completed
# 1651th data completed
# 1652th data completed
# 1653th data completed
# 1654th data completed
# 1655th data completed
# 1656th data completed
# 1657th data completed
# 1658th data completed
# 1659th data completed
# 1660th data completed
# 1661th data completed
# 1662th data completed
# 1663th data completed
# 1664th data completed
# 1665th data completed
# 1666th data completed
# 1667th data completed
# 1668th data completed
# 1669th data completed
# 1670th data completed
# 1671th data completed
# 1672th data completed
# 1673th data completed
# 1674th data completed
# 1675th data completed
# 1676th data completed
# 1677th data completed
# 1678th data completed
# 1679th data completed
# 1680th data completed
# 1681th data completed
# 1682th data completed
# 1683th data completed
# 1684th data completed
# 1685th data completed
# 1686th data completed
# 1687th data completed
# 1688th data completed
# 1689th data completed
# 1690th data completed
# 1691th data completed
# 1692th data completed
# 1693th data completed
# 1694th data completed
# 1695th data completed
# 1696th data completed
# 1697th data completed
# 1698th data completed
# 1699th data completed
# 1700th data completed
# 1701th data completed
# 1702th data completed
# 1703th data completed
# 1704th data completed
# 1705th data completed
# 1706th data completed
# 1707th data completed
# 1708th data completed
# 1709th data completed
# 1710th data completed
# 1711th data completed
# 1712th data completed
# 1713th data completed
# 1714th data completed
# 1715th data completed
# 1716th data completed
# 1717th data completed
# 1718th data completed
# 1719th data completed
# 1720th data completed
# 1721th data completed
# 1722th data completed
# 1723th data completed
# 1724th data completed
# 1725th data completed
# 1726th data completed
# 1727th data completed
# 1728th data completed
# 1729th data completed
# 1730th data completed
# 1731th data completed
# 1732th data completed
# 1733th data completed
# 1734th data completed
# 1735th data completed
# 1736th data completed
# 1737th data completed
# 1738th data completed
# 1739th data completed
# 1740th data completed
# 1741th data completed
# 1742th data completed
# 1743th data completed
# 1744th data completed
# 1745th data completed
# 1746th data completed
# 1747th data completed
# 1748th data completed
# 1749th data completed
# 1750th data completed
# 1751th data completed
# 1752th data completed
# 1753th data completed
# 1754th data completed
# 1755th data completed
# 1756th data completed
# 1757th data completed
# 1758th data completed
# 1759th data completed
# 1760th data completed
# 1761th data completed
# 1762th data completed
# 1763th data completed
# 1764th data completed
# 1765th data completed
# 1766th data completed
# 1767th data completed
# 1768th data completed
# 1769th data completed
# 1770th data completed
# 1771th data completed
# 1772th data completed
# 1773th data completed
# 1774th data completed
# 1775th data completed
# 1776th data completed
# 1777th data completed
# 1778th data completed
# 1779th data completed
# 1780th data completed
# 1781th data completed
# 1782th data completed
# 1783th data completed
# 1784th data completed
# 1785th data completed
# 1786th data completed
# 1787th data completed
# 1788th data completed
# 1789th data completed
# 1790th data completed
# 1791th data completed
# 1792th data completed
# 1793th data completed
# 1794th data completed
# 1795th data completed
# 1796th data completed
# 1797th data completed
# 1798th data completed
# 1799th data completed
# 1800th data completed
# 1801th data completed
# 1802th data completed
# 1803th data completed
# 1804th data completed
# 1805th data completed
# 1806th data completed
# 1807th data completed
# 1808th data completed
# 1809th data completed
# 1810th data completed
# 1811th data completed
# 1812th data completed
# 1813th data completed
# 1814th data completed
# 1815th data completed
# 1816th data completed
# 1817th data completed
# 1818th data completed
# 1819th data completed
# 1820th data completed
# 1821th data completed
# 1822th data completed
# 1823th data completed
# 1824th data completed
# 1825th data completed
# 1826th data completed
# 1827th data completed
# 1828th data completed
# 1829th data completed
# 1830th data completed
# 1831th data completed
# 1832th data completed
# 1833th data completed
# 1834th data completed
# 1835th data completed
# 1836th data completed
# 1837th data completed
# 1838th data completed
# 1839th data completed
# 1840th data completed
# 1841th data completed
# 1842th data completed
# 1843th data completed
# 1844th data completed
# 1845th data completed
# 1846th data completed
# 1847th data completed
# 1848th data completed
# 1849th data completed
# 1850th data completed
# 1851th data completed
# 1852th data completed
# 1853th data completed
# 1854th data completed
# 1855th data completed
# 1856th data completed
# 1857th data completed
# 1858th data completed
# 1859th data completed
# 1860th data completed
# 1861th data completed
# 1862th data completed
# 1863th data completed
# 1864th data completed
# 1865th data completed
# 1866th data completed
# 1867th data completed
# 1868th data completed
# 1869th data completed
# 1870th data completed
# 1871th data completed
# 1872th data completed
# 1873th data completed
# 1874th data completed
# 1875th data completed
# 1876th data completed
# 1877th data completed
# 1878th data completed
# 1879th data completed
# 1880th data completed
# 1881th data completed
# 1882th data completed
# 1883th data completed
# 1884th data completed
# 1885th data completed
# 1886th data completed
# 1887th data completed
# 1888th data completed
# 1889th data completed
# 1890th data completed
# 1891th data completed
# 1892th data completed
# 1893th data completed
# 1894th data completed
# 1895th data completed
# 1896th data completed
# 1897th data completed
# 1898th data completed
# 1899th data completed
# 1900th data completed
# 1901th data completed
# 1902th data completed
# 1903th data completed
# 1904th data completed
# 1905th data completed
# 1906th data completed
# 1907th data completed
# 1908th data completed
# 1909th data completed
# 1910th data completed
# 1911th data completed
# 1912th data completed
# 1913th data completed
# 1914th data completed
# 1915th data completed
# 1916th data completed
# 1917th data completed
# 1918th data completed
# 1919th data completed
# 1920th data completed
# 1921th data completed
# 1922th data completed
# 1923th data completed
# 1924th data completed
# 1925th data completed
# 1926th data completed
# 1927th data completed
# 1928th data completed
# 1929th data completed
# 1930th data completed
# 1931th data completed
# 1932th data completed
# 1933th data completed
# 1934th data completed
# 1935th data completed
# 1936th data completed
# 1937th data completed
# 1938th data completed
# 1939th data completed
# 1940th data completed
# 1941th data completed
# 1942th data completed
# 1943th data completed
# 1944th data completed
# 1945th data completed
# 1946th data completed
# 1947th data completed
# 1948th data completed
# 1949th data completed
# 1950th data completed
# 1951th data completed
# 1952th data completed
# 1953th data completed
# 1954th data completed
# 1955th data completed
# 1956th data completed
# 1957th data completed
# 1958th data completed
# 1959th data completed
# 1960th data completed
# 1961th data completed
# 1962th data completed
# 1963th data completed
# 1964th data completed
# 1965th data completed
# 1966th data completed
# 1967th data completed
# 1968th data completed
# 1969th data completed
# 1970th data completed
# 1971th data completed
# 1972th data completed
# 1973th data completed
# 1974th data completed
# 1975th data completed
# 1976th data completed
# 1977th data completed
# 1978th data completed
# 1979th data completed
# 1980th data completed
# 1981th data completed
# 1982th data completed
# 1983th data completed
# 1984th data completed
# 1985th data completed
# 1986th data completed
# 1987th data completed
# 1988th data completed
# 1989th data completed
# 1990th data completed
# 1991th data completed
# 1992th data completed
# 1993th data completed
# 1994th data completed
# 1995th data completed
# 1996th data completed
# 1997th data completed
# 1998th data completed
# 1999th data completed
# 2000th data completed
# 2001th data completed
# 2002th data completed
# 2003th data completed
# 2004th data completed
# 2005th data completed
# 2006th data completed
# 2007th data completed
# 2008th data completed
# 2009th data completed
# 2010th data completed
# 2011th data completed
# 2012th data completed
# 2013th data completed
# 2014th data completed
# 2015th data completed
# 2016th data completed
# 2017th data completed
# 2018th data completed
# 2019th data completed
# 2020th data completed
# 2021th data completed
# 2022th data completed
# 2023th data completed
# 2024th data completed
# 2025th data completed
# 2026th data completed
# 2027th data completed
# 2028th data completed
# 2029th data completed
# 2030th data completed
# 2031th data completed
# 2032th data completed
# 2033th data completed
# 2034th data completed
# 2035th data completed
# 2036th data completed
# 2037th data completed
# 2038th data completed
# 2039th data completed
# 2040th data completed
# 2041th data completed
# 2042th data completed
# 2043th data completed
# 2044th data completed
# 2045th data completed
# 2046th data completed
# 2047th data completed
# 2048th data completed
# 2049th data completed
# 2050th data completed
# 2051th data completed
# 2052th data completed
# 2053th data completed
# 2054th data completed
# 2055th data completed
# 2056th data completed
# 2057th data completed
# 2058th data completed
# 2059th data completed
# 2060th data completed
# 2061th data completed
# 2062th data completed
# 2063th data completed
# 2064th data completed
# 2065th data completed
# 2066th data completed
# 2067th data completed
# 2068th data completed
# 2069th data completed
# 2070th data completed
# 2071th data completed
# 2072th data completed
# 2073th data completed
# 2074th data completed
# 2075th data completed
# 2076th data completed
# 2077th data completed
# 2078th data completed
# 2079th data completed
# 2080th data completed
# 2081th data completed
# 2082th data completed
# 2083th data completed
# 2084th data completed
# 2085th data completed
# 2086th data completed
# 2087th data completed
# 2088th data completed
# 2089th data completed
# 2090th data completed
# 2091th data completed
# 2092th data completed
# 2093th data completed
# 2094th data completed
# 2095th data completed
# 2096th data completed
# 2097th data completed
# 2098th data completed
# 2099th data completed
# 2100th data completed
# 2101th data completed
# 2102th data completed
# 2103th data completed
# 2104th data completed
# 2105th data completed
# 2106th data completed
# 2107th data completed
# 2108th data completed
# 2109th data completed
# 2110th data completed
# 2111th data completed
# 2112th data completed
# 2113th data completed
# 2114th data completed
# 2115th data completed
# 2116th data completed
# 2117th data completed
# 2118th data completed
# 2119th data completed
# 2120th data completed
# 2121th data completed
# 2122th data completed
# 2123th data completed
# 2124th data completed
# 2125th data completed
# 2126th data completed
# 2127th data completed
# 2128th data completed
# 2129th data completed
# 2130th data completed
# 2131th data completed
# 2132th data completed
# 2133th data completed
# 2134th data completed
# 2135th data completed
# 2136th data completed
# 2137th data completed
# 2138th data completed
# 2139th data completed
# 2140th data completed
# 2141th data completed
# 2142th data completed
# 2143th data completed
# 2144th data completed
# 2145th data completed
# 2146th data completed
# 2147th data completed
# 2148th data completed
# 2149th data completed
# 2150th data completed
# 2151th data completed
# 2152th data completed
# 2153th data completed
# 2154th data completed
# 2155th data completed
# 2156th data completed
# 2157th data completed
# 2158th data completed
# 2159th data completed
# 2160th data completed
# 2161th data completed
# 2162th data completed
# 2163th data completed
# 2164th data completed
# 2165th data completed
# 2166th data completed
# 2167th data completed
# 2168th data completed
# 2169th data completed
# 2170th data completed
# 2171th data completed
# 2172th data completed
# 2173th data completed
# 2174th data completed
# 2175th data completed
# 2176th data completed
# 2177th data completed
# 2178th data completed
# 2179th data completed
# 2180th data completed
# 2181th data completed
# 2182th data completed
# 2183th data completed
# 2184th data completed
# 2185th data completed
# 2186th data completed
# 2187th data completed
# 2188th data completed
# 2189th data completed
# 2190th data completed
# 2191th data completed
# 2192th data completed
# 2193th data completed
# 2194th data completed
# 2195th data completed
# 2196th data completed
# 2197th data completed
# 2198th data completed
# 2199th data completed
# 2200th data completed
# 2201th data completed
# 2202th data completed
# 2203th data completed
# 2204th data completed
# 2205th data completed
# 2206th data completed
# 2207th data completed
# 2208th data completed
# 2209th data completed
# 2210th data completed
# 2211th data completed
# 2212th data completed
# 2213th data completed
# 2214th data completed
# 2215th data completed
# 2216th data completed
# 2217th data completed
# 2218th data completed
# 2219th data completed
# 2220th data completed
# 2221th data completed
# 2222th data completed
# 2223th data completed
# 2224th data completed
# 2225th data completed
# 2226th data completed
# 2227th data completed
# 2228th data completed
# 2229th data completed
# 2230th data completed
# 2231th data completed
# ...
# 1199th data completed
# 1200th data completed
# 1201th data completed
# 1202th data completed
# 1203th data completed
# 1204th data completed
# 1205th data completed
# 1206th data completed
# 1207th data completed
# 1208th data completed
# 1209th data completed
# 1210th data completed
# 1211th data completed
# 1212th data completed
# 1213th data completed
# 1214th data completed
# 1215th data completed
# 1216th data completed
# 1217th data completed
# 1218th data completed
# 1219th data completed
# 1220th data completed
# 1221th data completed
# 1222th data completed
# 1223th data completed
# 1224th data completed
# 1225th data completed
# 1226th data completed
# 1227th data completed
# 1228th data completed
# 1229th data completed
# 1230th data completed
# 1231th data completed
# 1232th data completed
# 1233th data completed
# 1234th data completed
# 1235th data completed
# 1236th data completed
# 1237th data completed
# 1238th data completed
# 1239th data completed
# 1240th data completed
# 1241th data completed
# 1242th data completed
# 1243th data completed
# 1244th data completed
# 1245th data completed
# 1246th data completed
# 1247th data completed
# 1248th data completed
# 1249th data completed
# 1250th data completed
# 1251th data completed
# 1252th data completed
# 1253th data completed
# 1254th data completed
# 1255th data completed
# 1256th data completed
# 1257th data completed
# 1258th data completed
# 1259th data completed
# 1260th data completed
# 1261th data completed
# 1262th data completed
# 1263th data completed
# 1264th data completed
# 1265th data completed
# 1266th data completed
# 1267th data completed
# 1268th data completed
# 1269th data completed
# 1270th data completed
# 1271th data completed
# 1272th data completed
# 1273th data completed
# 1274th data completed
# 1275th data completed
# 1276th data completed
# 1277th data completed
# 1278th data completed
# 1279th data completed
# 1280th data completed
# 1281th data completed
# 1282th data completed
# 1283th data completed
# 1284th data completed
# 1285th data completed
# 1286th data completed
# 1287th data completed
# 1288th data completed
# 1289th data completed
# 1290th data completed
# 1291th data completed
# 1292th data completed
# 1293th data completed
# 1294th data completed
# 1295th data completed
# 1296th data completed
# 1297th data completed
# 1298th data completed
# 1299th data completed
# 1300th data completed
# 1301th data completed
# 1302th data completed
# 1303th data completed
# 1304th data completed
# 1305th data completed
# 1306th data completed
# 1307th data completed
# 1308th data completed
# 1309th data completed
# 1310th data completed
# 1311th data completed
# 1312th data completed
# 1313th data completed
# 1314th data completed
# 1315th data completed
# 1316th data completed
# 1317th data completed
# 1318th data completed
# 1319th data completed
# 1320th data completed
# 1321th data completed
# 1322th data completed
# 1323th data completed
# 1324th data completed
# 1325th data completed
# 1326th data completed
# 1327th data completed
# 1328th data completed
# 1329th data completed
# 1330th data completed
# 1331th data completed
# 1332th data completed
# 1333th data completed
# 1334th data completed
# 1335th data completed
# 1336th data completed
# 1337th data completed
# 1338th data completed
# 1339th data completed
# 1340th data completed
# 1341th data completed
# 1342th data completed
# 1343th data completed
# 1344th data completed
# 1345th data completed
# 1346th data completed
# 1347th data completed
# 1348th data completed
# 1349th data completed
# 1350th data completed
# 1351th data completed
# 1352th data completed
# 1353th data completed
# 1354th data completed
# 1355th data completed
# 1356th data completed
# 1357th data completed
# 1358th data completed
# 1359th data completed
# 1360th data completed
# 1361th data completed
# 1362th data completed
# 1363th data completed
# 1364th data completed
# 1365th data completed
# 1366th data completed
# 1367th data completed
# 1368th data completed
# 1369th data completed
# 1370th data completed
# 1371th data completed
# 1372th data completed
# 1373th data completed
# 1374th data completed
# 1375th data completed
# 1376th data completed
# 1377th data completed
# 1378th data completed
# 1379th data completed
# 1380th data completed
# 1381th data completed
# 1382th data completed
# 1383th data completed
# 1384th data completed
# 1385th data completed
# 1386th data completed
# 1387th data completed
# 1388th data completed
# 1389th data completed
# 1390th data completed
# 1391th data completed
# 1392th data completed
# 1393th data completed
# 1394th data completed
# 1395th data completed
# 1396th data completed
# 1397th data completed
# 1398th data completed
# 1399th data completed
# 1400th data completed
# 1401th data completed
# 1402th data completed
# 1403th data completed
# 1404th data completed
# 1405th data completed
# 1406th data completed
# 1407th data completed
# 1408th data completed
# 1409th data completed
# 1410th data completed
# 1411th data completed
# 1412th data completed
# 1413th data completed
# 1414th data completed
# 1415th data completed
# 1416th data completed
# 1417th data completed
# 1418th data completed
# 1419th data completed
# 1420th data completed
# 1421th data completed
# 1422th data completed
# 1423th data completed
# 1424th data completed
# 1425th data completed
# 1426th data completed
# 1427th data completed
# 1428th data completed
# 1429th data completed
# 1430th data completed
# 1431th data completed
# 1432th data completed
# 1433th data completed
# 1434th data completed
# 1435th data completed
# 1436th data completed
# 1437th data completed
# 1438th data completed
# 1439th data completed
# 1440th data completed
# 1441th data completed
# 1442th data completed
# 1443th data completed
# 1444th data completed
# 1445th data completed
# 1446th data completed
# 1447th data completed
# 1448th data completed
# 1449th data completed
# 1450th data completed
# 1451th data completed
# 1452th data completed
# 1453th data completed
# 1454th data completed
# 1455th data completed
# 1456th data completed
# 1457th data completed
# 1458th data completed
# 1459th data completed
# 1460th data completed
# 1461th data completed
# 1462th data completed
# 1463th data completed
# 1464th data completed
# 1465th data completed
# 1466th data completed
# 1467th data completed
# 1468th data completed
# 1469th data completed
# 1470th data completed
# 1471th data completed
# 1472th data completed
# 1473th data completed
# 1474th data completed
# 1475th data completed
# 1476th data completed
# 1477th data completed
# 1478th data completed
# 1479th data completed
# 1480th data completed
# 1481th data completed
# 1482th data completed
# 1483th data completed
# 1484th data completed
# 1485th data completed
# 1486th data completed
# 1487th data completed
# 1488th data completed
# 1489th data completed
# 1490th data completed
# 1491th data completed
# 1492th data completed
# 1493th data completed
# 1494th data completed
# 1495th data completed
# 1496th data completed
# 1497th data completed
# 1498th data completed
# 1499th data completed
# 1500th data completed
# 1501th data completed
# 1502th data completed
# 1503th data completed
# 1504th data completed
# 1505th data completed
# 1506th data completed
# 1507th data completed
# 1508th data completed
# 1509th data completed
# 1510th data completed
# 1511th data completed
# 1512th data completed
# 1513th data completed
# 1514th data completed
# 1515th data completed
# 1516th data completed
# 1517th data completed
# 1518th data completed
# 1519th data completed
# 1520th data completed
# 1521th data completed
# 1522th data completed
# 1523th data completed
# 1524th data completed
# 1525th data completed
# 1526th data completed
# 1527th data completed
# 1528th data completed
# 1529th data completed
# 1530th data completed
# 1531th data completed
# 1532th data completed
# 1533th data completed
# 1534th data completed
# 1535th data completed
# 1536th data completed
# 1537th data completed
# 1538th data completed
# 1539th data completed
# 1540th data completed
# 1541th data completed
# 1542th data completed
# 1543th data completed
# 1544th data completed
# 1545th data completed
# 1546th data completed
# 1547th data completed
# 1548th data completed
# 1549th data completed
# 1550th data completed
# 1551th data completed
# 1552th data completed
# 1553th data completed
# 1554th data completed
# 1555th data completed
# 1556th data completed
# 1557th data completed
# 1558th data completed
# 1559th data completed
# 1560th data completed
# 1561th data completed
# 1562th data completed
# 1563th data completed
# 1564th data completed
# 1565th data completed
# 1566th data completed
# 1567th data completed
# 1568th data completed
# 1569th data completed
# 1570th data completed
# 1571th data completed
# 1572th data completed
# 1573th data completed
# 1574th data completed
# 1575th data completed
# 1576th data completed
# 1577th data completed
# 1578th data completed
# 1579th data completed
# 1580th data completed
# 1581th data completed
# 1582th data completed
# 1583th data completed
# 1584th data completed
# 1585th data completed
# 1586th data completed
# 1587th data completed
# 1588th data completed
# 1589th data completed
# 1590th data completed
# 1591th data completed
# 1592th data completed
# 1593th data completed
# 1594th data completed
# 1595th data completed
# 1596th data completed
# 1597th data completed
# 1598th data completed
# 1599th data completed
# 1600th data completed
# 1601th data completed
# 1602th data completed
# 1603th data completed
# 1604th data completed
# 1605th data completed
# 1606th data completed
# 1607th data completed
# 1608th data completed
# 1609th data completed
# 1610th data completed
# 1611th data completed
# 1612th data completed
# 1613th data completed
# 1614th data completed
# 1615th data completed
# 1616th data completed
# 1617th data completed
# 1618th data completed
# 1619th data completed
# 1620th data completed
# 1621th data completed
# 1622th data completed
# 1623th data completed
# 1624th data completed
# 1625th data completed
# 1626th data completed
# 1627th data completed
# 1628th data completed
# 1629th data completed
# 1630th data completed
# 1631th data completed
# 1632th data completed
# 1633th data completed
# 1634th data completed
# 1635th data completed
# 1636th data completed
# 1637th data completed
# 1638th data completed
# 1639th data completed
# 1640th data completed
# 1641th data completed
# 1642th data completed
# 1643th data completed
# 1644th data completed
# 1645th data completed
# 1646th data completed
# 1647th data completed
# 1648th data completed
# 1649th data completed
# 1650th data completed
# 1651th data completed
# 1652th data completed
# 1653th data completed
# 1654th data completed
# 1655th data completed
# 1656th data completed
# 1657th data completed
# 1658th data completed
# 1659th data completed
# 1660th data completed
# 1661th data completed
# 1662th data completed
# 1663th data completed
# 1664th data completed
# 1665th data completed
# 1666th data completed
# 1667th data completed
# 1668th data completed
# 1669th data completed
# 1670th data completed
# 1671th data completed
# 1672th data completed
# 1673th data completed
# 1674th data completed
# 1675th data completed
# 1676th data completed
# 1677th data completed
# 1678th data completed
# 1679th data completed
# 1680th data completed
# 1681th data completed
# 1682th data completed
# 1683th data completed
# 1684th data completed
# 1685th data completed
# 1686th data completed
# 1687th data completed
# 1688th data completed
# 1689th data completed
# 1690th data completed
# 1691th data completed
# 1692th data completed
# 1693th data completed
# 1694th data completed
# 1695th data completed
# 1696th data completed
# 1697th data completed
# 1698th data completed
# 1699th data completed
# 1700th data completed
# 1701th data completed
# 1702th data completed
# 1703th data completed
# 1704th data completed
# 1705th data completed
# 1706th data completed
# 1707th data completed
# 1708th data completed
# 1709th data completed
# 1710th data completed
# 1711th data completed
# 1712th data completed
# 1713th data completed
# 1714th data completed
# 1715th data completed
# 1716th data completed
# 1717th data completed
# 1718th data completed
# 1719th data completed
# 1720th data completed
# 1721th data completed
# 1722th data completed
# 1723th data completed
# 1724th data completed
# 1725th data completed
# 1726th data completed
# 1727th data completed
# 1728th data completed
# 1729th data completed
# 1730th data completed
# 1731th data completed
# 1732th data completed
# 1733th data completed
# 1734th data completed
# 1735th data completed
# 1736th data completed
# 1737th data completed
# 1738th data completed
# 1739th data completed
# 1740th data completed
# 1741th data completed
# 1742th data completed
# 1743th data completed
# 1744th data completed
# 1745th data completed
# 1746th data completed
# 1747th data completed
# 1748th data completed
# 1749th data completed
# 1750th data completed
# 1751th data completed
# 1752th data completed
# 1753th data completed
# 1754th data completed
# 1755th data completed
# 1756th data completed
# 1757th data completed
# 1758th data completed
# 1759th data completed
# 1760th data completed
# 1761th data completed
# 1762th data completed
# 1763th data completed
# 1764th data completed
# 1765th data completed
# 1766th data completed
# 1767th data completed
# 1768th data completed
# 1769th data completed
# 1770th data completed
# 1771th data completed
# 1772th data completed
# 1773th data completed
# 1774th data completed
# 1775th data completed
# 1776th data completed
# 1777th data completed
# 1778th data completed
# 1779th data completed
# 1780th data completed
# 1781th data completed
# 1782th data completed
# 1783th data completed
# 1784th data completed
# 1785th data completed
# 1786th data completed
# 1787th data completed
# 1788th data completed
# 1789th data completed
# 1790th data completed
# 1791th data completed
# 1792th data completed
# 1793th data completed
# 1794th data completed
# 1795th data completed
# 1796th data completed
# 1797th data completed
# 1798th data completed
# 1799th data completed
# 1800th data completed
# 1801th data completed
# 1802th data completed
# 1803th data completed
# 1804th data completed
# 1805th data completed
# 1806th data completed
# 1807th data completed
# 1808th data completed
# 1809th data completed
# 1810th data completed
# 1811th data completed
# 1812th data completed
# 1813th data completed
# 1814th data completed
# 1815th data completed
# 1816th data completed
# 1817th data completed
# 1818th data completed
# 1819th data completed
# 1820th data completed
# 1821th data completed
# 1822th data completed
# 1823th data completed
# 1824th data completed
# 1825th data completed
# 1826th data completed
# 1827th data completed
# 1828th data completed
# 1829th data completed
# 1830th data completed
# 1831th data completed
# 1832th data completed
# 1833th data completed
# 1834th data completed
# 1835th data completed
# 1836th data completed
# 1837th data completed
# 1838th data completed
# 1839th data completed
# 1840th data completed
# 1841th data completed
# 1842th data completed
# 1843th data completed
# 1844th data completed
# 1845th data completed
# 1846th data completed
# 1847th data completed
# 1848th data completed
# 1849th data completed
# 1850th data completed
# 1851th data completed
# 1852th data completed
# 1853th data completed
# 1854th data completed
# 1855th data completed
# 1856th data completed
# 1857th data completed
# 1858th data completed
# 1859th data completed
# 1860th data completed
# 1861th data completed
# 1862th data completed
# 1863th data completed
# 1864th data completed
# 1865th data completed
# 1866th data completed
# 1867th data completed
# 1868th data completed
# 1869th data completed
# 1870th data completed
# 1871th data completed
# 1872th data completed
# 1873th data completed
# 1874th data completed
# 1875th data completed
# 1876th data completed
# 1877th data completed
# 1878th data completed
# 1879th data completed
# 1880th data completed
# 1881th data completed
# 1882th data completed
# 1883th data completed
# 1884th data completed
# 1885th data completed
# 1886th data completed
# 1887th data completed
# 1888th data completed
# 1889th data completed
# 1890th data completed
# 1891th data completed
# 1892th data completed
# 1893th data completed
# 1894th data completed
# 1895th data completed
# 1896th data completed
# 1897th data completed
# 1898th data completed
# 1899th data completed
# 1900th data completed
# 1901th data completed
# 1902th data completed
# 1903th data completed
# 1904th data completed
# 1905th data completed
# 1906th data completed
# 1907th data completed
# 1908th data completed
# 1909th data completed
# 1910th data completed
# 1911th data completed
# 1912th data completed
# 1913th data completed
# 1914th data completed
# 1915th data completed
# 1916th data completed
# 1917th data completed
# 1918th data completed
# 1919th data completed
# 1920th data completed
# 1921th data completed
# 1922th data completed
# 1923th data completed
# 1924th data completed
# prediction json generated!!
